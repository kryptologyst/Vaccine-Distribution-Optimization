# %% [markdown]
# # Vaccine Distribution Optimization - Quick Start
#
# This notebook demonstrates the basic usage of the vaccine distribution optimization package.

# %%
import sys
from pathlib import Path

# Add src to path
sys.path.append(str(Path.cwd() / "src"))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from vaccine_distribution.data import VaccineDataGenerator, VaccineDataProcessor
from vaccine_distribution.models import (
    BaselineRegressor,
    GradientBoostingRegressor,
    NeuralNetworkRegressor
)
from vaccine_distribution.evaluation import VaccineEvaluator
from vaccine_distribution.visualization import VaccineVisualizer

# Set style
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
